# %%
# %matplotlib inline

# %%
from LoopStructural import GeologicalModel
from LoopStructural.visualisation import LavaVuModelViewer
from LoopStructural.datasets import load_claudius #demo data

import pandas as pd
import glob
import numpy as np
#import surfe

# %%
data = pd.read_excel(r'C:\Users\ASUS\Desktop\loopstructural\data perthbasin\perthbasin.xlsx')

# %%
data = data.rename(columns={'azimuth': 'strike', 'formation': 'feature_name'})

# %%
print(data)
# Out:
#                  X             Y            Z  val      strike       dip  \
# 0    393936.142320  6.693633e+06   957.702303    1  263.276747  1.193492
# 1    396918.892567  6.693984e+06   977.204803    1   83.276747  0.349367
# 2    351487.758871  6.688629e+06 -7385.646697    1   83.277000  6.546000
# 3    338518.168564  6.650709e+06 -4542.306605    1  256.590252  1.789915
# 4    397464.032464  6.663078e+06   959.378895    1  268.100891  1.432093
# ..             ...           ...          ...  ...         ...       ...
# 119  353033.649500  6.688811e+06 -5424.239697    5         NaN       NaN
# 120  341942.065600  6.651525e+06 -4152.902105    5         NaN       NaN
# 121  342823.407600  6.651735e+06 -4152.902105    5         NaN       NaN
# 122  337375.397500  6.650011e+06 -1199.239105    5         NaN       NaN
# 123  338177.661300  6.650617e+06 -1227.176105    5         NaN       NaN
#
#      polarity  coord feature_name
# 0         1.0    NaN      Permian
# 1         1.0    NaN      Permian
# 2         1.0    NaN      Permian
# 3         1.0    NaN      Permian
# 4         1.0    NaN      Permian
# ..        ...    ...          ...
# 119       NaN    NaN      Eneabba
# 120       NaN    NaN      Eneabba
# 121       NaN    NaN      Eneabba
# 122       NaN    NaN      Eneabba
# 123       NaN    NaN      Eneabba
#
# [124 rows x 9 columns]

# %%
data_claudius, bb_claudius = load_claudius()

# %%
print(bb_claudius)

# %%
##extent_of_model = np.array([[ 340944.288072, 6637386.,  -7357.485252],
## [ 393936.142320,  6693633.,   957.702303]])

extent_of_model= np.array([[337000,6640000,-18000],  ##taken from extent of model in gempy
[400000,6710000,1000]])

# %%
print(extent_of_model[0,:])
# Out:
# [ 337000 6640000  -18000]

# %%
print(extent_of_model[1,:])
# Out:
# [ 400000 6710000    1000]

# %%
data['feature_name'].unique()

viewer = LavaVuModelViewer(background='white')
viewer.add_value_data(data[~np.isnan(data['val'])][['X','Y','Z']],data[~np.isnan(data['val'])]['val'],name='value points')
viewer.add_vector_data(data[~np.isnan(data['dip'])][['X','Y','Z']],
                       data[~np.isnan(data['strike'])][['X','Y','Z']],name='orientation points')
viewer.rotate([-85.18760681152344, 42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# 2021-10-13 00:26:43,372 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# 2021-10-13 00:26:43,372 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# 2021-10-13 00:26:43,372 ~ LoopStructural.visualisation.model_visualisation ~ ERROR      ~ Plot area has not been defined.
# <img src='data:image/png;base64,...'>

# %%
fault_displacement = 500

model = GeologicalModel(extent_of_model[0,:],extent_of_model[1,:])
model.set_model_data(data)


fault_Coomallo = model.create_and_add_fault('Coomallo',
                              fault_displacement,
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )

formation_Permian = model.create_and_add_foliation('Permian',
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )

#uc = model.add_unconformity(formation_Permian,1)




fault_Darling = model.create_and_add_fault('Darling',
                                fault_displacement,
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )



formation_Cretaceous   =    model.create_and_add_foliation('Cretaceous',
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )


fault_Hypo_fault_E = model.create_and_add_fault('Hypo_fault_E',
                              fault_displacement,
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )


formation_Yarragadee  =    model.create_and_add_foliation('Yarragadee',
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Hypo_fault_W = model.create_and_add_fault('Hypo_fault_W',
                              fault_displacement,
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )


formation_Lesueur   =     model.create_and_add_foliation('Lesueur',
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )


fault_Urella_North = model.create_and_add_fault('Urella_North',
                               fault_displacement,                 
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )


formation_Eneabba   =   model.create_and_add_foliation('Eneabba',
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Urella_South = model.create_and_add_fault('Urella_South',
                            fault_displacement,
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )
fault_Abrolhos_Transfer = model.create_and_add_fault('Abrolhos_Transfer',
                            fault_displacement,
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                              )

fault_Eneabba_south = model.create_and_add_fault('Eneabba_South',
                               fault_displacement,                  
                              interpolatortype='FDI',
                               nelements=1e4,
                               solver='pyamg'
                               )

model.update()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=29.0), HTML(value='')))
# 2021-10-13 00:26:49,492 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:26:49,492 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:26:49,524 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Coomallo_0 scalar field 0. Add more data.
# 2021-10-13 00:26:49,524 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Coomallo_0 scalar field 0. Add more data.
# C:\Users\ASUS\AppData\Local\conda\conda\envs\tf\lib\site-packages\LoopStructural\modelling\features\geological_feature_builder.py:251: RuntimeWarning: invalid value encountered in true_divide
#   vector /= np.linalg.norm(vector,axis=1)[:,None]
# 2021-10-13 00:26:49,764 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:26:49,764 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:10,607 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:10,607 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:32,754 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:32,754 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:51,320 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:51,320 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:53,427 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:53,427 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:53,437 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Darling_0 scalar field 0. Add more data.
# 2021-10-13 00:27:53,437 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Darling_0 scalar field 0. Add more data.
# 2021-10-13 00:27:53,672 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:27:53,672 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:12,451 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:12,451 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:34,607 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:34,607 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:53,107 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:53,107 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:55,347 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:55,347 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:55,353 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Hypo_fault_E_0 scalar field 0. Add more data.
# 2021-10-13 00:28:55,353 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Hypo_fault_E_0 scalar field 0. Add more data.
# 2021-10-13 00:28:55,594 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:28:55,594 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:14,745 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:14,745 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:37,907 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:37,907 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:56,871 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:56,871 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:59,031 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:59,031 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:59,047 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Hypo_fault_W_0 scalar field 0. Add more data.
# 2021-10-13 00:29:59,047 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Hypo_fault_W_0 scalar field 0. Add more data.
# 2021-10-13 00:29:59,279 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:29:59,279 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:30:17,712 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:30:17,712 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:30:39,827 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:30:39,827 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:30:58,310 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:30:58,310 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:31:00,534 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:31:00,534 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:31:00,550 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Urella_North_0 scalar field 0. Add more data.
# 2021-10-13 00:31:00,550 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Urella_North_0 scalar field 0. Add more data.
# 2021-10-13 00:31:00,832 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:31:00,832 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:31:19,485 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:31:19,485 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:31:41,411 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:31:41,411 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:32:00,443 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:32:00,443 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:32:59,679 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:32:59,679 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:32:59,693 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Urella_South_0 scalar field 0. Add more data.
# 2021-10-13 00:32:59,693 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Urella_South_0 scalar field 0. Add more data.
# 2021-10-13 00:32:59,954 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:32:59,954 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:33:18,423 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:33:18,423 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:33:41,173 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:33:41,173 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:33:59,630 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:33:59,630 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:33:59,644 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Abrolhos_Transfer_0 scalar field 0. Add more data.
# 2021-10-13 00:33:59,644 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Abrolhos_Transfer_0 scalar field 0. Add more data.
# 2021-10-13 00:33:59,875 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:33:59,875 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:34:18,827 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:34:18,827 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:34:40,860 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:34:40,860 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:34:59,602 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:34:59,602 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:34:59,622 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Eneabba_South_0 scalar field 0. Add more data.
# 2021-10-13 00:34:59,622 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ No solution, Eneabba_South_0 scalar field 0. Add more data.
# 2021-10-13 00:34:59,865 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:34:59,865 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:35:18,409 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:35:18,409 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:35:40,864 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead
# 2021-10-13 00:35:40,864 ~ LoopStructural.interpolators.discrete_interpolator ~ WARNING    ~ Pyamg not installed using cg instead

# %%
#model.update()

viewer = LavaVuModelViewer(model)


viewer.add_isosurface(formation_Permian,
#                       nslices=5
                     colour = 'blue'
                     ) ##slices=[2,1.5,1],





viewer.add_isosurface(formation_Cretaceous,
#                       nslices=5,
                      colour = 'red'
                     )


viewer.add_isosurface(formation_Yarragadee,
#                       nslices=5
                   colour = 'yellow'
                  )


viewer.add_isosurface(formation_Lesueur,
#                       nslices=5
                      colour = 'brown'
                     )



viewer.add_isosurface(formation_Eneabba,
#                       nslices=5
                      
                     paint_with=formation_Eneabba)




viewer.add_isosurface(fault_Coomallo,
#                       nslices=5
                      isovalue=7.,
                     paint_with=fault_Coomallo)


viewer.add_isosurface(fault_Darling,
                     isovalue=7.,
                     paint_with=fault_Darling)

viewer.add_isosurface(fault_Hypo_fault_E,
                  isovalue=8.,
                     paint_with=fault_Hypo_fault_E)

viewer.add_isosurface(fault_Hypo_fault_W,
                  isovalue=9.,
                     paint_with=fault_Hypo_fault_W)

viewer.add_isosurface(fault_Urella_North ,
                    isovalue=4.,
                     paint_with=fault_Urella_North )

viewer.add_isosurface(fault_Urella_South,
                     isovalue=4,
                     paint_with=fault_Urella_South)

viewer.add_isosurface(fault_Abrolhos_Transfer,
                  isovalue=4,
                     paint_with=fault_Abrolhos_Transfer)


viewer.add_isosurface(fault_Eneabba_south,
                isovalue=4,
                     paint_with=fault_Eneabba_south)


viewer.rotate([-85.18760681152344, -42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# 2021-10-13 01:09:10,444 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,444 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,444 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,524 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,524 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,524 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,623 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,623 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,623 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,706 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,706 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,706 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,805 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,805 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,805 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,889 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,889 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,889 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,973 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,973 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:10,973 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:11,070 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:11,070 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# 2021-10-13 01:09:11,070 ~ LoopStructural.visualisation.model_visualisation ~ WARNING    ~ Isovalue doesn't exist inside bounding box
# <img src='data:image/png;base64,...'>

# %%
viewer.rotate([-175.18760681152344, -42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>

# %%
viewer.rotate([85.18760681152344, -42.93233871459961, -0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>

# %%
viewer.rotate([85.18760681152344, -42.93233871459961, 0.8641873002052307])
viewer.display()
# Out:
# <img src='data:image/png;base64,...'>

# %%
stratigraphic_column = {}
stratigraphic_column['Permian'] = {}
stratigraphic_column['Permian']['unit1'] = {'min':1,'max':10,'id':0}

stratigraphic_column['Coomallo'] = {}
stratigraphic_column['Coomallo']['unit2'] = {'min':-60,'max':0,'id':1}
stratigraphic_column['Coomallo']['unit3'] = {'min':-250,'max':-60,'id':2}
stratigraphic_column['Coomallo']['unit4'] = {'min':-330,'max':-250,'id':3}
stratigraphic_column['Coomallo']['unit5'] = {'min':-360,'max':-330,'id':4}



stratigraphic_column['Cretaceous'] = {}
stratigraphic_column['Cretaceous']['unit8'] = {'min':-490,'max':-450,'id':7}
stratigraphic_column['Cretaceous']['unit9'] = {'min':-520,'max':-490,'id':8}

stratigraphic_column['Yarragadee'] = {}
stratigraphic_column['Yarragadee']['unit10'] = {'min':-560,'max':-520,'id':9}
stratigraphic_column['Yarragadee']['unit11'] = {'min':-np.inf,'max':-560,'id':10}

# %%
model.set_stratigraphic_column(stratigraphic_column)

viewer = LavaVuModelViewer(model)
viewer.add_model(cmap='tab20')
viewer.rotate([85.18760681152344, -42.93233871459961, -0.8641873002052307])
viewer.display()

# %%
viewer.rotate([-85.18760681152344, -42.93233871459961, -0.8641873002052307])
viewer.display()

# %%
viewer = LavaVuModelViewer(model)
viewer.add_model_surfaces(cmap='tab20')
viewer.rotate([-85.18760681152344, -42.93233871459961, -0.8641873002052307])
viewer.display()
